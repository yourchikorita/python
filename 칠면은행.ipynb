# %%
import time

print('안녕, 어서와. 우리 은행은 처음이지? \n')

num=0
cho=0
cho1=0
cho2=0
cho3=3
cho3_1=0
cho3_2=0
cho4=0

saving=0
sa1=0

move_money=0
bank_name='0'
bank_number=0
final_confirm=0

foreign= 0
exchange= 0
currency= 0
send_money= 0

if num !=5:
	num = int(input('원하는 업무를 선택해줘! {1. 예금 2. 대출 3. 이체 4. 외환 5.종료} : '))

if num == 1:
  if saving !=4: 
    saving = int(input('어떤 예금업무를 도와줄까? {1. 예금추천 2.예,적금검색 3.예,적금가입 4.해지}'))
  
  #예금추천
  if saving == 1:
    if sa1 !=2:
      sa1 = int(input('너에게 필요한 예,적금 상품이 있어. 알려줄까? {1. 스마트통장 2. 정기적금} : '))      
      if sa1 == 1:
        print('스마트통장은 현물이 없는 통장이야. 가입해줘~~')
      if sa1 == 2:
        print('너가 가입하기 좋은 장기적금이야, 가입해볼래?')

  #예,적금검색     
  if saving == 2:
    sa2 = input('어떤 예,적금을 찾고있니? 예)7면통장, 7면정기적금')
    print('{}이 걸 찾아주면 될까?'.format(sa2))
  
  #예,적금가입
  if saving == 3:
    print('통장 계설할려고? 고마워')

  #해지  
  if saving == 4:
    print('해지할려고ㅠㅠ 다음에 좋은 상품으로 찾아갈께~') 
  
elif num == 2:

    if cho !=5:
	    cho = int(input('원하는 메뉴를 선택해줘! {1. 대출안내 2. 한도조회 3. 대출신청 4. 신청현황 5.종료} : '))

if cho == 1:
    cho1 = int(input('안내를 원하시는 대출상품을 말씀해주세요 {1. 신용대출 2. 담보대출} : '))
if cho1 == 1:
        print('신용대출 상품안내서 보러가기')
  
if cho1 == 2:
        print('담보대출 상품안내서 보러가기')
if cho == 2:
        cho2 = int(input('한도 조회해줄까요? {1. 예 2. 아니오} : '))
        if cho2 == 1:
            print('잠시만 기다려주세요')
            time.sleep(5)
            print('100억까지 대출 가능하십니다')
            time.sleep(5)
            print('이용해주셔서 감사합니다')
        if cho2 == 2:
            print('안녕히 가세요')
if cho == 3:
        cho3 = int(input('대출상품 선택 {1. 신용대출 2. 담보대출} : '))
        if cho3 == 1:
            cho_3 = int(input('선택하신 대출상품으로 진행할까요? {1. 예 2. 아니오} : '))
            if cho_3 == 1:
                print('정상적으로 대출 신청되셨습니다')
            if cho_3 == 2:
                print('안녕히 가세요')
        if cho3 == 2:
            cho_3 = int(input('선택하신 대출상품으로 진행할까요? {1. 예 2. 아니오} : '))
            if cho_3 == 1:
                print('정상적으로 대출 신청되셨습니다')
            if cho_3 == 2:
                print('안녕히 가세요')
if cho == 4:
        cho4 = int(input('신청하신 대출상품을 조회해드릴까요? : {1. 예 2. 아니오} : '))
        if cho4 == 1:
            print('조회화면 보러가기')
        if cho4 == 2:
            print('안녕히 가세요')
if cho == 5:
    print('종료되었습니다')
elif num == 3:
    move_money = int(input('안녕 이체를 선택한 당신!  빠르고 간편하게 내가 도와줄게! 얼마를 송금할꺼야? 숫자만 입력 예) 000(원) : '))
    print('무려 {} (원) 을 이체 하겠다구? 부자가 여깄었네!'.format(move_money))
    bank_name = input(' 이체를 원하는 은행명을 입력해줘 예)칠면은행 : ')
    print('{}이라니! 요즘 핫한 은행을 사용하는군! '.format(bank_name))
    bank_number = int(input('송금받을 계좌번호를 입력해줘 (숫자만 입력): '))
    print('{}({})으로 {}원  "전은정" 님에게 정말로 이체해도 되겠니? 혹시라도 검찰, 경찰, 금융감독원이나 모르는 사람이 전화로 대출 및 이체를 요청했다면 보이스피싱이야!'.format(bank_name,bank_number,move_money ))
    final_confirm = int(input(' {1.보이스피싱 같아! 이체 취소할게 고마워! 2. 이체할께!} : '))
    if final_confirm == 1:
        print('보이스피싱을 사전에 막아내다니 참 다행이야! 앞으로도 은행 일이 필요하면 언제든지 말 걸어줘')
    if final_confirm ==2:
        print('"전은정"님께 {}이체 끝! 앞으로도 은행 일이 필요하면 언제든지 말 걸어줘'.format(move_money))
  
elif num == 4:
  print('외환 업무가 필요하니? 잘 왔어. ㅋㅋ 외화상품이랑 환전 중 필요한 걸 말해줘 :')

if num != 3:
	num = int(input('외환업무는 {1.외환상품 2.환전 3.외화송금}:'))

if num == 1:
    print('- 외화상품이 궁금하구나?')
    foreign= int(input('- 일정기간 거치하는 "외화정기예금"을 원하면 1번,정기적으로 외화를 적립하는 "외화적립예금"을 원하면 2번을 눌러줘'))
    if foreign == 1:
        print('너를 위해 준비했어^^ 꼭 읽어봐. 외환정기예금 상품안내서 보러가기')
    if foreign == 2:
        print('외화저축을 시작한 너^^ 외환정립예금 상품안내서 보러가기')
    
if num == 2:
    print('- 외화환전이 필요하구나?')
    exchange= int(input('외화로 환전(원화->외화)을 원하면 1번, 원화로 환전(외화->원화)을 원하면 2번을 눌러줘'))

    # 환전(원화->외화)
    if exchange == 1:
        print('- 원화를 외화로 환전(원화->외화)을 원하는구나.', '어떤 외화로 환전할지 아래 보기에서 골라줘')
        currency= int(input('1번 달러, 2번 엔화, 3번 위안화, 4번 유로화'))
        if currency == 1:
            dollor= int(input('환전할 금액을 달러 금액으로 적어줄래'))
            print('{}달러 -> {}원'.format(dollor, dollor*1210))
        if currency == 2:
            yen= int(input('환전할 금액을 엔화 금액으로 적어줄래'))
            print('{}엔 -> {}원'.format(yen, yen*11.34))
        if currency == 3:
            wien= int(input('환전할 금액을 위안화 금액으로 적어줄래'))
            print('{}위안 -> {}원'.format(wien, wien*168))
        if currency == 4:
            yuro= int(input('환전할 금액을 유로화 금액으로 적어줄래'))
            print('{}유로 -> {}원'.format(yuro, yuro*1324))

    # 환전(외화->원화)
    if exchange == 2:
        print('- 외화를 원화로 환전(외화->원화)을 원하는구나.','어떤 외화를 환전할지 아래 보기에서 골라줘')
        currency= int(input('1번 달러, 2번 엔화, 3번 위안화, 4번 유로화'))
        if currency == 1:
            dollor= int(input('환전할 달러금액을 적어줄래'))
            print('{}달러 -> {}원 환전 완료^^'.format(dollor, dollor*1210))
        if currency == 2:
            yen= int(input('환전할 엔화금액을 적어줄래'))
            print('{}엔 -> {}원 환전 완료^^'.format(yen, yen*11.34))
        if currency == 3:
            wien= int(input('환전할 위안화 금액을 적어줄래'))
            print('{}위안 -> {}원 환전 완료^^'.format(wien, wien*168))
        if currency == 4:
            yuro= int(input('환전할 유로화 금액을 적어줄래'))
            print('{}유로 -> {}원 환전 완료^^'.format(yuro, yuro*1324))

# 외화 송금
if  exchange== 3:
    print('- 외화송금이 필요하구나?')
    send_money= int(input('- 어떤 외화를 송금하고 싶어? 1.달러, 2.엔화, 3.위안화 4.유로화'))
    if send_money == 1:
       dolor= int(input('환전할 금액을 달러 금액으로 적어줄래'))
       print('{}달러 송금 완료^^'.format(dollor))
    if send_money == 2:
       yen= int(input('환전할 금액을 엔화 금액으로 적어줄래'))
       print('{}엔 송금 완료^^'.format(yen))
    if send_money == 3:
       wien= int(input('환전할 금액을 위안화 금액으로 적어줄래'))
       print('{}위안 송금 완료^^'.format(wien))
    if send_money == 4:
       yuro= int(input('환전할 금액을 유로화 금액으로 적어줄래'))
       print('{}유로 송금 완료^^'.format(yuro))

elif num == 5:
  print('안녕~~~ 다음에 또 봐')
# Out:
# 안녕, 어서와. 우리 은행은 처음이지?
#
# 원하는 업무를 선택해줘! {1. 예금 2. 대출 3. 이체 4. 외환 5.종료} : 4
# 외환 업무가 필요하니? 잘 왔어. ㅋㅋ 외화상품이랑 환전 중 필요한 걸 말해줘 :
# 외환업무는 {1.외환상품 2.환전 3.외화송금}:2
# - 외화환전이 필요하구나?
# 외화로 환전(원화->외화)을 원하면 1번, 원화로 환전(외화->원화)을 원하면 2번을 눌러줘1
# - 원화를 외화로 환전(원화->외화)을 원하는구나. 어떤 외화로 환전할지 아래 보기에서 골라줘
# 1번 달러, 2번 엔화, 3번 위안화, 4번 유로화4
# 환전할 금액을 유로화 금액으로 적어줄래100000
# 100000유로 -> 132400000원
